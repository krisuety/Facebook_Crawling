# %% [markdown]
# ### 1. selenium을 이용한 페이스북 크롤링

# %% [markdown]
# 초기설정

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
import time
import pandas as pd

# %% [markdown]
# 크롬 접속시 환경 설정에 관해서 물어보는 창을 무시함

# %%
chrome_options = webdriver.ChromeOptions()
prefs = {"profile.default_content_setting_values.notifications" : 2}
chrome_options.add_experimental_option("prefs",prefs)
driver = webdriver.Chrome(chrome_options=chrome_options)

# %% [markdown]
# facebook 접속

# %%
driver.get("https://www.facebook.com")
time.sleep(3)

# %% [markdown]
# id와 pw를 입력하고 로그인 버튼을 클릭

# %%
driver.find_element_by_css_selector("#email").send_keys('id')
driver.find_element_by_css_selector("#pass").send_keys('pw')
driver.find_element_by_css_selector("#loginbutton").click()
time.sleep(3)

# %% [markdown]
# 크롤링하고 싶은 페이지로 이동

# %%
driver.get("https://www.facebook.com/huffpost")
time.sleep(3)

# %% [markdown]
# 크롤링할 페이지

# %% [markdown]
# ![huff](material/huffpost.png)

# %% [markdown]
# 2005년 5월 아리아나 허핑턴이 설립한 미국의 리버럴, 신좌파성향 인터넷 신문이다.
#
# 설립 당시의 이름은 허핑턴포스트(The Huffington Post) 였으며 2017년에 애칭이었던 허프포스트(Huffpost)로 개칭했다.

# %% [markdown]
# 페이지 관리자와 채팅 할 수 있는 조그만 창이 밑에 뜨는데 그것을 꺼지게 함

# %%
if driver.find_elements_by_css_selector("._32ca"):
    while True:
        try:
            driver.find_element_by_css_selector("._32ca").click()
            break
        except:
            time.sleep(3)

# %% [markdown]
# 페이지 내의 게시물 탭으로 이동

# %%
driver.find_element_by_css_selector("#entity_sidebar > div:nth-child(3) > div:nth-child(5) > a > span._2yav").click()

# %% [markdown]
# 페이스북 html 구조

# %%
first_string = "._1xnd ._4-u2._4-u8 ._4-u2._4-u8" # 게시물 페이지에 들어갔을때 처음으로 나오는 속성
date = "._5pcq abbr" # 게시물이 올라온 날짜
content = ".userContent p" # 게시물의 내용
comment = "._ipn.clearfix._-5d ._ipo a" # 게시물의 댓글 및 공유
emotion = "._ipp > ._3t53 > span > a" # 게시물의 리액션 (좋아요, 등등)
add_string = "._1xnd " # add_string 문자열을 first_string과 더해주면 하위 속성으로 들어갈 수 있음
num = 1
ls = []

# %% [markdown]
# ![facebookimg](facebookhtml.png)

# %%
today = 2018117 # 크롤링을 몇일까지 할 것인지를 정해줌
while True:
    posts = driver.find_elements_by_css_selector(first_string)
    for post in posts:
        # for문을 돌리면서 속성들을 비교하고, 없다면 null값을 넣어줌
        ls.append(num)
        ls.append(post.find_element_by_css_selector(date).get_attribute("title"))
        try:
            ls.append(post.find_element_by_css_selector(content).text)
        except:
            ls.append("NULL")
        try:
            ls.append(post.find_elements_by_css_selector(comment)[0].text)
        except:
            ls.append("NULL")
        try:
            ls.append(post.find_elements_by_css_selector(comment)[1].text)
        except:
            ls.append("NULL")
        try:
            ls.append(post.find_elements_by_css_selector(emotion)[0].get_attribute("aria-label"))
        except:
            ls.append("NULL")
        try:
            ls.append(post.find_elements_by_css_selector(emotion)[1].get_attribute("aria-label"))
        except:
            ls.append("NULL")
        try:
            ls.append(post.find_elements_by_css_selector(emotion)[2].get_attribute("aria-label"))
        except:
            ls.append("NULL")
        num += 1
    #for문을 사용해 한 페이지의 게시물 내용, 댓글갯수, 공유수 등을 리스트에 추가함
    
    first_string = add_string + first_string
    # 첫 페이지에서 while문이 break가 걸릴때까지 안의 속성으로 들어갈 수 있도록 만들어 줌
    
    try:
        driver.find_element_by_css_selector("#www_pages_reaction_see_more_unitwww_pages_posts").click() #스크롤을 내림
        time.sleep(5)
    except:
        pass
    
    if int(ls[-7][:9].replace("-","")) < today:
        break #날짜 속성을 숫자로 바꾸고, 크롤링을 시작하고 싶은 날짜보다 작다면 break

# %% [markdown]
# while 문에서는 8개 단위로 크롤링을 하고 append 해주기 때문에 크롤링을 시작하고 싶은 날짜를 포함하고 있는 8개의 게시물이 모두 출력된다.
#
# 이를 걸러주기 위해 리스트 내의 날짜 속성을 비교해 크롤링을 시작하고 싶은 날짜의 게시물을 걸러준다.

# %%
for i in range(int(len(ls)/8)):
    if int(ls[1 + 8*i][:9].replace("-","")) < today:
        ls_today = ls[:8*i]
        break # 멈춘 페이지에서 크롤링 하고 싶은 날

# %% [markdown]
# 리스트 출력

# %%
ls_today[-16:]
# Out:
# [158,
#  '2018-11-7 오전 12:33',
#  '"I thought you would have more important things to do... before an election — like sucking up to the guy who called your wife ugly and accused your dad of murder."',
#  '댓글 289개',
#  '공유 895회',
#  '좋아요 3.6천개',
#  '웃겨요 2.6천개',
#  '최고예요 319개',
#  159,
#  '2018-11-7 오전 12:00',
#  'Trademarks hold the promise of profit for the senior White House adviser and daughter of the president.',
#  '댓글 1.3천개',
#  '공유 6,762회',
#  '화나요 8.9천개',
#  '멋져요 1.5천개',
#  '좋아요 814개']

# %% [markdown]
# ### 2. 데이터 프레임 생성

# %% [markdown]
# 리액션별로 컬럼을 만들고, 리스트에서 속성을 뽑아내서 넣어준다

# %%
df = pd.DataFrame(columns=["날짜", "내용", "댓글", "공유", "좋아요", "화나요", "웃겨요", "멋져요", "슬퍼요", "최고예요"])

# %%
for i in range(int(len(ls_today)/8)):
    if ls_today[5 + i*8] == "NULL":
        dic = {
                    "날짜": ls_today[1 + i*8],
                    "내용": ls_today[2 + i*8],
                    "댓글": ls_today[3 + i*8].split(" ")[1][:-1],
                    "공유": ls_today[4 + i*8].split(" ")[1][:-1],
                }
    elif ls_today[6 + i*8] == "NULL":
        dic = {
                    "날짜": ls_today[1 + i*8],
                    "내용": ls_today[2 + i*8],
                    "댓글": ls_today[3 + i*8].split(" ")[1][:-1],
                    "공유": ls_today[4 + i*8].split(" ")[1][:-1],
                    ls_today[5 + i*8].split(" ")[0]: ls_today[5 + i*8].split(" ")[1][:-1],
                }
    elif ls_today[7 + i*8] == "NULL":
        dic = {
                    "날짜": ls_today[1 + i*8],
                    "내용": ls_today[2 + i*8],
                    "댓글": ls_today[3 + i*8].split(" ")[1][:-1],
                    "공유": ls_today[4 + i*8].split(" ")[1][:-1],
                    ls_today[5 + i*8].split(" ")[0]: ls_today[5 + i*8].split(" ")[1][:-1],
                    ls_today[6 + i*8].split(" ")[0]: ls_today[6 + i*8].split(" ")[1][:-1],
                }
    else:
        dic = {
                    "날짜": ls_today[1 + i*8],
                    "내용": ls_today[2 + i*8],
                    "댓글": ls_today[3 + i*8].split(" ")[1][:-1],
                    "공유": ls_today[4 + i*8].split(" ")[1][:-1],
                    ls_today[5 + i*8].split(" ")[0]: ls_today[5 + i*8].split(" ")[1][:-1],
                    ls_today[6 + i*8].split(" ")[0]: ls_today[6 + i*8].split(" ")[1][:-1],
                    ls_today[7 + i*8].split(" ")[0]: ls_today[7 + i*8].split(" ")[1][:-1],

                }
    df = df.append(dic, ignore_index=True)

# %%
df
# Out:
#                      날짜                                                 내용  \
# 0    2018-11-9 오전 01:15  The senator once said firing Jeff Sessions wou...
# 1    2018-11-9 오전 01:01  Matt Wennerstrom, 20, said he threw barstools ...
# 2    2018-11-9 오전 12:45  Despite hopes for a truce between the presiden...
# 3    2018-11-9 오전 12:30  Don Lemon says Donald Trump's off-the-rails pr...
# 4    2018-11-9 오전 12:15  12 people were killed after a gunman opened fi...
# 5    2018-11-9 오전 12:00  A heartbreaking account of the mass shooting a...
# 6    2018-11-8 오후 11:30  Ginsburg was admitted to George Washington Uni...
# 7    2018-11-8 오후 11:00    This is one rat that won't be bullied by a cat.
# 8    2018-11-8 오후 10:30                      Another Trump promise broken.
# 9    2018-11-8 오후 10:00  Lindsey Graham once promised "holy hell to pay...
# 10   2018-11-8 오후 09:30  The White House is accused of engaging in "Orw...
# 11   2018-11-8 오후 09:15  The White House Correspondents’ Association ca...
# 12   2018-11-8 오후 09:01  A gunman killed 12 people, including sheriff s...
# 13   2018-11-8 오후 08:30  "Trump has accidentally given Jeff Sessions an...
# 14   2018-11-8 오후 08:00  Experts explain why there are benefits to this...
# 15   2018-11-8 오후 07:30  "The idea they’ve come up with, I’m startled,"...
# 16   2018-11-8 오후 07:00  “I’m a feminist, but I think that this third-w...
# 17   2018-11-8 오후 06:30  "I wish we had more time to spend with our clo...
# 18   2018-11-8 오후 06:00  Jada Pinkett Smith and Leah Remini decided to ...
# 19   2018-11-8 오후 05:00                 According to educators themselves.
# 20   2018-11-8 오후 04:00                                      So relatable.
# 21   2018-11-8 오후 03:00  Fans were shocked when they heard this name dr...
# 22   2018-11-8 오후 02:30  You’ve never seen Russell Crowe like this before.
# 23   2018-11-8 오후 02:00  Stephen Colbert has the worst insult Donald Tr...
# 24   2018-11-8 오후 01:00  The New York State Senate finally has some Asi...
# 25   2018-11-8 오후 12:00                                   This is awkward.
# 26   2018-11-8 오전 11:00  What's it like to view the midterms through th...
# 27   2018-11-8 오전 10:30  After a long night of watching election result...
# 28   2018-11-8 오전 10:13               Acosta shared video of the incident.
# 29   2018-11-8 오전 10:00  A British woman’s engagement to a ghost she me...
# ..                  ...                                                ...
# 129  2018-11-7 오전 10:43  The Kentucky clerk made headlines after refusi...
# 130  2018-11-7 오전 10:36  The "Battle of the Billionaires" was the most ...
# 131  2018-11-7 오전 10:11                                               NULL
# 132  2018-11-7 오전 09:55  Women are dominating #Midterms2018, and they’r...
# 133  2018-11-7 오전 09:53  Democrats have picked up their first House sea...
# 134  2018-11-7 오전 09:04  Kaine, his party’s 2016 vice presidential cand...
# 135  2018-11-7 오전 08:57  Voting hasn’t been going smoothly for many peo...
# 136  2018-11-7 오전 08:30  By taking a plea deal, the Frederick, Colorado...
# 137  2018-11-7 오전 08:25            Beyoncé has weighed in on the midterms.
# 138  2018-11-7 오전 08:00  Demi Lovato is looking happy and healthy in a ...
# 139  2018-11-7 오전 07:30  Long lines, locked buildings and broken machin...
# 140  2018-11-7 오전 07:15  A new study from the United Nations just gave ...
# 141  2018-11-7 오전 07:02  Taylor Swift issued a final plea Tuesday to he...
# 142  2018-11-7 오전 06:45  Central American migrants left their native co...
# 143  2018-11-7 오전 06:31  Fox News is “having a schizophrenic moment ove...
# 144  2018-11-7 오전 06:00  “We want him to win, and we’ll be watching the...
# 145  2018-11-7 오전 05:31  NBC chose to air a racist Trump ad during “Sun...
# 146  2018-11-7 오전 05:16                                               NULL
# 147  2018-11-7 오전 05:00  Susan B. Anthony was arrested for voting almos...
# 148  2018-11-7 오전 04:30  Voters from across the country are waiting in ...
# 149  2018-11-7 오전 04:00  King signed off from talking politics, but not...
# 150  2018-11-7 오전 03:32       “You cannot take this election for granted."
# 151  2018-11-7 오전 03:02  “I heard people were making racist robocalls i...
# 152  2018-11-7 오전 02:40  “The folks you are about to see are not early ...
# 153  2018-11-7 오전 02:16  Mark Salter, the late Arizona Republican’s for...
# 154  2018-11-7 오전 02:15  Here’s how the late-night comedians covered th...
# 155  2018-11-7 오전 01:30  After bragging that America was “winning at ev...
# 156  2018-11-7 오전 01:02  "This is absolutely Dave Chappelle, the comedi...
# 157  2018-11-7 오전 12:33  "I thought you would have more important thing...
# 158  2018-11-7 오전 12:00  Trademarks hold the promise of profit for the ...
#
#        댓글      공유   좋아요   화나요   웃겨요   멋져요   슬퍼요  최고예요
# 0      51      22    21    24    32   NaN   NaN   NaN
# 1      21      37    63   NaN   NaN    13   135   NaN
# 2     248      49    77   270    43   NaN   NaN   NaN
# 3     154     104   817   NaN    75   NaN   NaN    57
# 4      95     112    39    76   NaN   NaN   222   NaN
# 5     101     198   175   180   NaN   NaN  1.8천   NaN
# 6     348     421    98   NaN   NaN   230  1.6천   NaN
# 7      29      83    81   NaN   163    21   NaN   NaN
# 8     403     940   918   658   289   NaN   NaN   NaN
# 9    1.2천   2,944  3.7천  1.2천  2.3천   NaN   NaN   NaN
# 10   1.8천   5,357  3.6천    1만   NaN  1.2천   NaN   NaN
# 11   1.9천   6,144  2.4만  2.5천   NaN   NaN   NaN  2.9천
# 12    204   1,586   NaN    1천   NaN   182  2.6천   NaN
# 13    124     187    1천   NaN  1.6천   NaN   NaN    47
# 14    116     310   366   NaN    35   NaN   NaN    19
# 15     24      30   260   NaN   NaN     7   NaN    26
# 16    527      57   185   719   278   NaN   NaN   NaN
# 17     14      11    43   NaN   NaN   NaN     1     2
# 18     19       8   318   NaN    11   NaN   NaN    16
# 19      5      31    71   NaN   NaN     1   NaN     4
# 20     44     510  1.5천   NaN    38   NaN   NaN   102
# 21     25       9   122   NaN    30   NaN   NaN    13
# 22      9       8    73   NaN   NaN    28   NaN     3
# 23      8      37   314   NaN    97   NaN   NaN    18
# 24     24     476  4.6천   NaN   NaN    13   NaN   653
# 25    674   1,499    1천   NaN  3.6천   622   NaN   NaN
# 26    153      79   187   171   724   NaN   NaN   NaN
# 27   1.3천   1,398   494  1.6천   985   NaN   NaN   NaN
# 28   3.9천   5,886  3.5천  1.8만   NaN  3.2천   NaN   NaN
# 29     81      70    52   NaN   111    11   NaN   NaN
# ..    ...     ...   ...   ...   ...   ...   ...   ...
# 129  1.9천   6,056  3.1만   NaN  8.4천   NaN   NaN  7.5천
# 130    96     762  6.7천   NaN   NaN   114   NaN    1천
# 131    43      24   167   NaN   NaN   NaN    35    42
# 132    15      62   300   NaN     2   NaN   NaN    65
# 133   333   1,859  1.9만   NaN   NaN    93   NaN  4.2천
# 134   555   2,814    3만   NaN   NaN   115   NaN    7천
# 135    68     127    93   211   NaN   NaN    69   NaN
# 136   385     330   398  2.1천   NaN   NaN   493   NaN
# 137   131      63    2천   NaN    19   NaN   NaN   295
# 138    36      26  1.5천   NaN     8   NaN   NaN   225
# 139   126     448   279   813   NaN    95   NaN   NaN
# 140    18      65   203   NaN   NaN    19   NaN    36
# 141    63      78  2.7천   NaN     9   NaN   NaN   314
# 142   128     121   147   NaN   NaN   NaN   182    18
# 143   168     105   692   103   150   NaN   NaN   NaN
# 144   143     633  5.8천   NaN    20   NaN   NaN  2.2천
# 145    73      63  1.2천   100   NaN   NaN   NaN    65
# 146    33      39    50   134   NaN   NaN    60   NaN
# 147   723  41,177  6.8만   NaN   NaN   651   NaN  2.7만
# 148    64     151  4.4천   NaN   NaN     7   NaN   613
# 149    57      67    1천   NaN    31   NaN   NaN   178
# 150    15      11   194   NaN    22   NaN   NaN    10
# 151   100     261  1.5천   NaN    31   NaN   NaN   211
# 152   102     113   220   NaN   228   NaN   158   NaN
# 153   137   1,170  7.2천   NaN   NaN   128   NaN   750
# 154    19      18   104   NaN    20   NaN   NaN     9
# 155   622     160   509   257    1천   NaN   NaN   NaN
# 156    32      92  1.6천   NaN    27   NaN   NaN   210
# 157   289     895  3.6천   NaN  2.6천   NaN   NaN   319
# 158  1.3천   6,762   814  8.9천   NaN  1.5천   NaN   NaN
#
# [159 rows x 10 columns]

# %%
df.tail()
# Out:
#                      날짜                                                 내용  \
# 154  2018-11-7 오전 02:15  Here’s how the late-night comedians covered th...
# 155  2018-11-7 오전 01:30  After bragging that America was “winning at ev...
# 156  2018-11-7 오전 01:02  "This is absolutely Dave Chappelle, the comedi...
# 157  2018-11-7 오전 12:33  "I thought you would have more important thing...
# 158  2018-11-7 오전 12:00  Trademarks hold the promise of profit for the ...
#
#        댓글     공유   좋아요   화나요   웃겨요   멋져요  슬퍼요 최고예요
# 154    19     18   104   NaN    20   NaN  NaN    9
# 155   622    160   509   257    1천   NaN  NaN  NaN
# 156    32     92  1.6천   NaN    27   NaN  NaN  210
# 157   289    895  3.6천   NaN  2.6천   NaN  NaN  319
# 158  1.3천  6,762   814  8.9천   NaN  1.5천  NaN  NaN

# %% [markdown]
# Null 값 처리

# %%
df = df.fillna(0)
df = df.astype(str)

# %%
df.tail()
# Out:
#                      날짜                                                 내용  \
# 154  2018-11-7 오전 02:15  Here’s how the late-night comedians covered th...
# 155  2018-11-7 오전 01:30  After bragging that America was “winning at ev...
# 156  2018-11-7 오전 01:02  "This is absolutely Dave Chappelle, the comedi...
# 157  2018-11-7 오전 12:33  "I thought you would have more important thing...
# 158  2018-11-7 오전 12:00  Trademarks hold the promise of profit for the ...
#
#        댓글     공유   좋아요   화나요   웃겨요   멋져요 슬퍼요 최고예요
# 154    19     18   104     0    20     0   0    9
# 155   622    160   509   257    1천     0   0    0
# 156    32     92  1.6천     0    27     0   0  210
# 157   289    895  3.6천     0  2.6천     0   0  319
# 158  1.3천  6,762   814  8.9천     0  1.5천   0    0

# %% [markdown]
# 7천을 7000으로, 1,599를 1599로 수정해서 비교하기 쉽게 만든다

# %%
for column in list(df.columns[2:]):
    for i in range(len(df)):
        if df[column][i][-1] == "천":
            df[column][i] = float(df[column][i][:-1]) * 1000
        elif df[column][i][-1] == "만":
            df[column][i] = float(df[column][i][:-1]) * 10000
    
df.공유 = df.공유.apply(lambda x: x.replace(",",""))

# %%
df.tail()
# Out:
#                      날짜                                                 내용  \
# 154  2018-11-7 오전 02:15  Here’s how the late-night comedians covered th...
# 155  2018-11-7 오전 01:30  After bragging that America was “winning at ev...
# 156  2018-11-7 오전 01:02  "This is absolutely Dave Chappelle, the comedi...
# 157  2018-11-7 오전 12:33  "I thought you would have more important thing...
# 158  2018-11-7 오전 12:00  Trademarks hold the promise of profit for the ...
#
#        댓글    공유   좋아요   화나요   웃겨요   멋져요 슬퍼요 최고예요
# 154    19    18   104     0    20     0   0    9
# 155   622   160   509   257  1000     0   0    0
# 156    32    92  1600     0    27     0   0  210
# 157   289   895  3600     0  2600     0   0  319
# 158  1300  6762   814  8900     0  1500   0    0

# %%
df
# Out:
#                      날짜                                                 내용  \
# 0    2018-11-9 오전 01:15  The senator once said firing Jeff Sessions wou...
# 1    2018-11-9 오전 01:01  Matt Wennerstrom, 20, said he threw barstools ...
# 2    2018-11-9 오전 12:45  Despite hopes for a truce between the presiden...
# 3    2018-11-9 오전 12:30  Don Lemon says Donald Trump's off-the-rails pr...
# 4    2018-11-9 오전 12:15  12 people were killed after a gunman opened fi...
# 5    2018-11-9 오전 12:00  A heartbreaking account of the mass shooting a...
# 6    2018-11-8 오후 11:30  Ginsburg was admitted to George Washington Uni...
# 7    2018-11-8 오후 11:00    This is one rat that won't be bullied by a cat.
# 8    2018-11-8 오후 10:30                      Another Trump promise broken.
# 9    2018-11-8 오후 10:00  Lindsey Graham once promised "holy hell to pay...
# 10   2018-11-8 오후 09:30  The White House is accused of engaging in "Orw...
# 11   2018-11-8 오후 09:15  The White House Correspondents’ Association ca...
# 12   2018-11-8 오후 09:01  A gunman killed 12 people, including sheriff s...
# 13   2018-11-8 오후 08:30  "Trump has accidentally given Jeff Sessions an...
# 14   2018-11-8 오후 08:00  Experts explain why there are benefits to this...
# 15   2018-11-8 오후 07:30  "The idea they’ve come up with, I’m startled,"...
# 16   2018-11-8 오후 07:00  “I’m a feminist, but I think that this third-w...
# 17   2018-11-8 오후 06:30  "I wish we had more time to spend with our clo...
# 18   2018-11-8 오후 06:00  Jada Pinkett Smith and Leah Remini decided to ...
# 19   2018-11-8 오후 05:00                 According to educators themselves.
# 20   2018-11-8 오후 04:00                                      So relatable.
# 21   2018-11-8 오후 03:00  Fans were shocked when they heard this name dr...
# 22   2018-11-8 오후 02:30  You’ve never seen Russell Crowe like this before.
# 23   2018-11-8 오후 02:00  Stephen Colbert has the worst insult Donald Tr...
# 24   2018-11-8 오후 01:00  The New York State Senate finally has some Asi...
# 25   2018-11-8 오후 12:00                                   This is awkward.
# 26   2018-11-8 오전 11:00  What's it like to view the midterms through th...
# 27   2018-11-8 오전 10:30  After a long night of watching election result...
# 28   2018-11-8 오전 10:13               Acosta shared video of the incident.
# 29   2018-11-8 오전 10:00  A British woman’s engagement to a ghost she me...
# ..                  ...                                                ...
# 129  2018-11-7 오전 10:43  The Kentucky clerk made headlines after refusi...
# 130  2018-11-7 오전 10:36  The "Battle of the Billionaires" was the most ...
# 131  2018-11-7 오전 10:11                                               NULL
# 132  2018-11-7 오전 09:55  Women are dominating #Midterms2018, and they’r...
# 133  2018-11-7 오전 09:53  Democrats have picked up their first House sea...
# 134  2018-11-7 오전 09:04  Kaine, his party’s 2016 vice presidential cand...
# 135  2018-11-7 오전 08:57  Voting hasn’t been going smoothly for many peo...
# 136  2018-11-7 오전 08:30  By taking a plea deal, the Frederick, Colorado...
# 137  2018-11-7 오전 08:25            Beyoncé has weighed in on the midterms.
# 138  2018-11-7 오전 08:00  Demi Lovato is looking happy and healthy in a ...
# 139  2018-11-7 오전 07:30  Long lines, locked buildings and broken machin...
# 140  2018-11-7 오전 07:15  A new study from the United Nations just gave ...
# 141  2018-11-7 오전 07:02  Taylor Swift issued a final plea Tuesday to he...
# 142  2018-11-7 오전 06:45  Central American migrants left their native co...
# 143  2018-11-7 오전 06:31  Fox News is “having a schizophrenic moment ove...
# 144  2018-11-7 오전 06:00  “We want him to win, and we’ll be watching the...
# 145  2018-11-7 오전 05:31  NBC chose to air a racist Trump ad during “Sun...
# 146  2018-11-7 오전 05:16                                               NULL
# 147  2018-11-7 오전 05:00  Susan B. Anthony was arrested for voting almos...
# 148  2018-11-7 오전 04:30  Voters from across the country are waiting in ...
# 149  2018-11-7 오전 04:00  King signed off from talking politics, but not...
# 150  2018-11-7 오전 03:32       “You cannot take this election for granted."
# 151  2018-11-7 오전 03:02  “I heard people were making racist robocalls i...
# 152  2018-11-7 오전 02:40  “The folks you are about to see are not early ...
# 153  2018-11-7 오전 02:16  Mark Salter, the late Arizona Republican’s for...
# 154  2018-11-7 오전 02:15  Here’s how the late-night comedians covered th...
# 155  2018-11-7 오전 01:30  After bragging that America was “winning at ev...
# 156  2018-11-7 오전 01:02  "This is absolutely Dave Chappelle, the comedi...
# 157  2018-11-7 오전 12:33  "I thought you would have more important thing...
# 158  2018-11-7 오전 12:00  Trademarks hold the promise of profit for the ...
#
#        댓글     공유    좋아요    화나요   웃겨요   멋져요   슬퍼요   최고예요
# 0      51     22     21     24    32     0     0      0
# 1      21     37     63      0     0    13   135      0
# 2     248     49     77    270    43     0     0      0
# 3     154    104    817      0    75     0     0     57
# 4      95    112     39     76     0     0   222      0
# 5     101    198    175    180     0     0  1800      0
# 6     348    421     98      0     0   230  1600      0
# 7      29     83     81      0   163    21     0      0
# 8     403    940    918    658   289     0     0      0
# 9    1200   2944   3700   1200  2300     0     0      0
# 10   1800   5357   3600  10000     0  1200     0      0
# 11   1900   6144  24000   2500     0     0     0   2900
# 12    204   1586      0   1000     0   182  2600      0
# 13    124    187   1000      0  1600     0     0     47
# 14    116    310    366      0    35     0     0     19
# 15     24     30    260      0     0     7     0     26
# 16    527     57    185    719   278     0     0      0
# 17     14     11     43      0     0     0     1      2
# 18     19      8    318      0    11     0     0     16
# 19      5     31     71      0     0     1     0      4
# 20     44    510   1500      0    38     0     0    102
# 21     25      9    122      0    30     0     0     13
# 22      9      8     73      0     0    28     0      3
# 23      8     37    314      0    97     0     0     18
# 24     24    476   4600      0     0    13     0    653
# 25    674   1499   1000      0  3600   622     0      0
# 26    153     79    187    171   724     0     0      0
# 27   1300   1398    494   1600   985     0     0      0
# 28   3900   5886   3500  18000     0  3200     0      0
# 29     81     70     52      0   111    11     0      0
# ..    ...    ...    ...    ...   ...   ...   ...    ...
# 129  1900   6056  31000      0  8400     0     0   7500
# 130    96    762   6700      0     0   114     0   1000
# 131    43     24    167      0     0     0    35     42
# 132    15     62    300      0     2     0     0     65
# 133   333   1859  19000      0     0    93     0   4200
# 134   555   2814  30000      0     0   115     0   7000
# 135    68    127     93    211     0     0    69      0
# 136   385    330    398   2100     0     0   493      0
# 137   131     63   2000      0    19     0     0    295
# 138    36     26   1500      0     8     0     0    225
# 139   126    448    279    813     0    95     0      0
# 140    18     65    203      0     0    19     0     36
# 141    63     78   2700      0     9     0     0    314
# 142   128    121    147      0     0     0   182     18
# 143   168    105    692    103   150     0     0      0
# 144   143    633   5800      0    20     0     0   2200
# 145    73     63   1200    100     0     0     0     65
# 146    33     39     50    134     0     0    60      0
# 147   723  41177  68000      0     0   651     0  27000
# 148    64    151   4400      0     0     7     0    613
# 149    57     67   1000      0    31     0     0    178
# 150    15     11    194      0    22     0     0     10
# 151   100    261   1500      0    31     0     0    211
# 152   102    113    220      0   228     0   158      0
# 153   137   1170   7200      0     0   128     0    750
# 154    19     18    104      0    20     0     0      9
# 155   622    160    509    257  1000     0     0      0
# 156    32     92   1600      0    27     0     0    210
# 157   289    895   3600      0  2600     0     0    319
# 158  1300   6762    814   8900     0  1500     0      0
#
# [159 rows x 10 columns]

# %% [markdown]
# ### 3. 함수 생성

# %%
def page_crawling(id, pw, page_url="https://www.facebook.com/huffpost", today="2018117"):
    
    # chorme 옵션, facebook을 들어갈 때 페이스북에서 알람을 보내는 것을 허용하겠냐는 chrome 알람이 뜨는데 
    # 이 알람은 alter로 처리할 수 있는 알람과는 다른 종류의 알람이므로 chromeoptions를 통해 알람이
    # 뜨지 않도록 한다.
    chrome_options = webdriver.ChromeOptions()
    prefs = {"profile.default_content_setting_values.notifications" : 2}
    chrome_options.add_experimental_option("prefs",prefs)
    driver = webdriver.Chrome(chrome_options=chrome_options)
    
    # facebook 접속
    driver.get("https://www.facebook.com")
    time.sleep(3)

    # id와 pw를 입력하고 로그인 버튼을 누름
    driver.find_element_by_css_selector("#email").send_keys(id)
    driver.find_element_by_css_selector("#pass").send_keys(pw)
    driver.find_element_by_css_selector("#loginbutton").click()
    time.sleep(3)
    
    # 크롤링하고 싶은 페이지로 이동
    driver.get(page_url)
    time.sleep(3)
    
    # 페이지 관리자와 채팅 할 수 있는 조그만 창이 밑에 뜨는데 그것을 꺼지게 함
    if driver.find_elements_by_css_selector("._32ca"):
        while True:
            try:
                driver.find_element_by_css_selector("._32ca").click()
                break
            except:
                time.sleep(3)
                
    # 페이지 내의 게시물 탭으로 이동
    driver.find_element_by_css_selector("#entity_sidebar > div:nth-child(3) > div:nth-child(5) > a > span._2yav").click()    
    time.sleep(2)
    
    first_string = "._1xnd ._4-u2._4-u8 ._4-u2._4-u8"
    date = "._5pcq abbr"
    content = ".userContent p"
    comment = "._ipn.clearfix._-5d ._ipo a"
    emotion = "._ipp > ._3t53 > span > a"
    add_string = "._1xnd "
    num = 1
    ls = []  
    
    # 게시물별로 접근
    while True:
        posts = driver.find_elements_by_css_selector(first_string)
        for post in posts:
            ls.append(num)
            ls.append(post.find_element_by_css_selector(date).get_attribute("title"))
            try:
                ls.append(post.find_element_by_css_selector(content).text)
            except:
                ls.append("NULL")
            try:
                ls.append(post.find_elements_by_css_selector(comment)[0].text)
            except:
                ls.append("NULL")
            try:
                ls.append(post.find_elements_by_css_selector(comment)[1].text)
            except:
                ls.append("NULL")
            try:
                ls.append(post.find_elements_by_css_selector(emotion)[0].get_attribute("aria-label"))
            except:
                ls.append("NULL")
            try:
                ls.append(post.find_elements_by_css_selector(emotion)[1].get_attribute("aria-label"))
            except:
                ls.append("NULL")
            try:
                ls.append(post.find_elements_by_css_selector(emotion)[2].get_attribute("aria-label"))
            except:
                ls.append("NULL")
            num += 1

        first_string = add_string + first_string

        try:
            driver.find_element_by_css_selector("#www_pages_reaction_see_more_unitwww_pages_posts").click()
            time.sleep(5)
        except:
            pass

        if int(ls[-7][:9].replace("-","")) < int(today):
            break
    
    
    for i in range(int(len(ls)/8)):
        if int(ls[1 + 8*i][:9].replace("-","")) < int(today):
            ls_today = ls[:8*i]
            break
            
    driver.quit()
    
    
    # 데이터프레임 생성
    df = pd.DataFrame(columns=["날짜", "내용", "댓글", "공유", "좋아요", "화나요", "웃겨요", "멋져요", "슬퍼요", "최고예요"])
    
    for i in range(int(len(ls_today)/8)):
        if ls_today[5 + i*8] == "NULL":
            dic = {
                        "날짜": ls_today[1 + i*8],
                        "내용": ls_today[2 + i*8],
                        "댓글": ls_today[3 + i*8].split(" ")[1][:-1],
                        "공유": ls_today[4 + i*8].split(" ")[1][:-1],
                    }
        elif ls_today[6 + i*8] == "NULL":
            dic = {
                        "날짜": ls_today[1 + i*8],
                        "내용": ls_today[2 + i*8],
                        "댓글": ls_today[3 + i*8].split(" ")[1][:-1],
                        "공유": ls_today[4 + i*8].split(" ")[1][:-1],
                        ls_today[5 + i*8].split(" ")[0]: ls_today[5 + i*8].split(" ")[1][:-1],
                    }
        elif ls_today[7 + i*8] == "NULL":
            dic = {
                        "날짜": ls_today[1 + i*8],
                        "내용": ls_today[2 + i*8],
                        "댓글": ls_today[3 + i*8].split(" ")[1][:-1],
                        "공유": ls_today[4 + i*8].split(" ")[1][:-1],
                        ls_today[5 + i*8].split(" ")[0]: ls_today[5 + i*8].split(" ")[1][:-1],
                        ls_today[6 + i*8].split(" ")[0]: ls_today[6 + i*8].split(" ")[1][:-1],
                    }
        else:
            dic = {
                        "날짜": ls_today[1 + i*8],
                        "내용": ls_today[2 + i*8],
                        "댓글": ls_today[3 + i*8].split(" ")[1][:-1],
                        "공유": ls_today[4 + i*8].split(" ")[1][:-1],
                        ls_today[5 + i*8].split(" ")[0]: ls_today[5 + i*8].split(" ")[1][:-1],
                        ls_today[6 + i*8].split(" ")[0]: ls_today[6 + i*8].split(" ")[1][:-1],
                        ls_today[7 + i*8].split(" ")[0]: ls_today[7 + i*8].split(" ")[1][:-1],
                    }
            
        df = df.append(dic, ignore_index=True)
       
    # NULL값 처리
    df = df.fillna(0)
    df = df.astype(str)

    # 개수가 천이 넘어가면 1천, 2.1천 이런 식으로 보여지는것을 숫자형으로 변환
    for column in list(df.columns[2:]):
        for i in range(len(df)):
            if df[column][i][-1] == "천":
                df[column][i] = float(df[column][i][:-1]) * 1000
            elif df[column][i][-1] == "만":
                df[column][i] = float(df[column][i][:-1]) * 10000

    df.공유 = df.공유.apply(lambda x: x.replace(",",""))
    df.내용[df.내용 == ""] = "NULL"

    return df

# %%
df = page_crawling('id','pw')
df.tail()
# Out:
#                      날짜                                                 내용  \
# 154  2018-11-7 오전 02:15  Here’s how the late-night comedians covered th...
# 155  2018-11-7 오전 01:30  After bragging that America was “winning at ev...
# 156  2018-11-7 오전 01:02  "This is absolutely Dave Chappelle, the comedi...
# 157  2018-11-7 오전 12:33  "I thought you would have more important thing...
# 158  2018-11-7 오전 12:00  Trademarks hold the promise of profit for the ...
#
#        댓글    공유   좋아요   화나요   웃겨요   멋져요 슬퍼요 최고예요
# 154    19    18   104     0    20     0   0    9
# 155   622   160   509   257  1000     0   0    0
# 156    32    92  1600     0    27     0   0  210
# 157   289   895  3600     0  2600     0   0  319
# 158  1300  6763   814  8900     0  1500   0    0

# %% [markdown]
# ### 4. word cloud

# %% [markdown]
# 초기 설정

# %%
import numpy as np
from wordcloud import WordCloud
from wordcloud import STOPWORDS
from PIL import Image
# %matplotlib inline
# %config InlineBackend.figure_formats = {'png', 'retina'}

# %% [markdown]
# word cloud 출력

# %%
mask_shape = np.array(Image.open("cloud.png"))
stopwords = set(STOPWORDS)
stopwords.add("NULL")

wordcloud = WordCloud(
                          background_color='white',
                          stopwords=stopwords,
                          max_words=200,
                          mask=mask_shape,
                          max_font_size=40, 
                          random_state=42
                         ).generate(str(df['내용']))

plt.figure(figsize=(8,8))
fig = plt.figure(1)
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.show()
fig.savefig("word1.png", dpi=900)

# %% [markdown]
# ![wc](material/download.png)

# %% [markdown]
# 그중 가장 많이 나온 단어 10개를 뽑아본다.

# %%
key = []
value = []
for i in wordcloud.words_:
    key.append(i)
    value.append(wordcloud.words_.get(i))
    
sns.barplot(key[:10], value[:10])

# %% [markdown]
# 11월 6일 미국의 중간선거(상의원,하의원,주지사 선거) 영향으로 관련 단어가 많이 사용됐음을 알 수 있다. (Trump, New, said, Donald)
#
# 또한 gunman 과 killed 라는 단어가 사용된 것으로 보아 총기사건이 발생했음을 유추할 수 있다.

# %% [markdown]
# [美 11·6 중간선거 실시 "트럼프 국정운영 분수령"](http://news.hankyung.com/article/2018110637687)

# %% [markdown]
# [[속보] 미국 LA 교외 술집서 총기난사](http://news.kbs.co.kr/news/view.do?ncd=4069668&ref=A)

# %% [markdown]
# ### 5. 감정 표현에 따른 regression

# %% [markdown]
# 좋아요를 제외한 반응을 사용한다

# %% [markdown]
# #### 5-1. 댓글

# %%
from sklearn.linear_model import LinearRegression
emoji = df[['화나요','웃겨요','멋져요','슬퍼요','최고예요']].astype(int)
target_reply = df['댓글'].astype(int)
emoji = sm.add_constant(emoji)
model = sm.OLS(target_reply, emoji)
result = model.fit()
print(result.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     댓글   R-squared:                       0.428
# Model:                            OLS   Adj. R-squared:                  0.410
# Method:                 Least Squares   F-statistic:                     22.92
# Date:                Fri, 09 Nov 2018   Prob (F-statistic):           3.93e-17
# Time:                        01:40:37   Log-Likelihood:                -1337.4
# No. Observations:                 159   AIC:                             2687.
# Df Residuals:                     153   BIC:                             2705.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        126.2065    101.009      1.249      0.213     -73.347     325.760
# 화나요            0.3585      0.044      8.068      0.000       0.271       0.446
# 웃겨요            0.2873      0.057      5.018      0.000       0.174       0.400
# 멋져요           -0.5274      0.243     -2.168      0.032      -1.008      -0.047
# 슬퍼요            0.0575      0.071      0.814      0.417      -0.082       0.197
# 최고예요           0.0430      0.026      1.678      0.095      -0.008       0.094
# ==============================================================================
# Omnibus:                      303.652   Durbin-Watson:                   1.888
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            79342.812
# Skew:                           9.590   Prob(JB):                         0.00
# Kurtosis:                     110.742   Cond. No.                     4.31e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.31e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# 위의 결과에서 보이듯이 화나요의 갯수가 댓글수에 가장 큰 영향을 미쳤으며 그다음 웃겨요가 영향을 미쳤다.
#
# 나머지 멋져요, 슬퍼요, 최고에요는 통계적으로 유의미한 결과가 있다고 할 수 없다.

# %% [markdown]
# #### 5-2. 공유

# %%
target_share = df['공유'].astype(int)
model2 = sm.OLS(target_share, emoji)
result2 = model2.fit()
print(result2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     공유   R-squared:                       0.894
# Model:                            OLS   Adj. R-squared:                  0.891
# Method:                 Least Squares   F-statistic:                     259.0
# Date:                Fri, 09 Nov 2018   Prob (F-statistic):           9.44e-73
# Time:                        01:40:40   Log-Likelihood:                -1377.5
# No. Observations:                 159   AIC:                             2767.
# Df Residuals:                     153   BIC:                             2785.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -294.0937    129.984     -2.263      0.025    -550.889     -37.299
# 화나요            0.4099      0.057      7.168      0.000       0.297       0.523
# 웃겨요            0.2382      0.074      3.233      0.001       0.093       0.384
# 멋져요            0.4740      0.313      1.514      0.132      -0.144       1.092
# 슬퍼요            0.0255      0.091      0.280      0.780      -0.154       0.205
# 최고예요           1.1092      0.033     33.675      0.000       1.044       1.174
# ==============================================================================
# Omnibus:                      126.489   Durbin-Watson:                   1.616
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4967.055
# Skew:                           2.281   Prob(JB):                         0.00
# Kurtosis:                      29.999   Cond. No.                     4.31e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.31e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# 위의 결과에서 보이듯이 최고예요가 공유에 가장 큰 영향을 미쳤다.
#
# 유의수준을 5%로 잡았을때 최고예요, 화나요, 웃겨요 순으로 공유수에 영향을 미쳤다.

# %% [markdown]
# 수정결정계수가 0.894로 이 모델의 설명력이 더 높다

# %% [markdown]
# ### 6. error case

# %%
dates_list = []
contents_list = []
comments_list = []
emotions_list = []
df = pd.DataFrame(columns=["날짜", "내용", "댓글", "공유", "좋아요", "화나요", "웃겨요", "멋져요", "슬퍼요", "최고예요"])

# 페이스북은 밑으로 내려야만 그 다음 게시물이 뜨기 때문에 초기에 입력한 날짜가 끝날 때까지 밑으로 내려가는 코드
while True:
    try: 
        driver.find_element_by_css_selector("#www_pages_reaction_see_more_unitwww_pages_posts").click()
        dates = driver.find_elements_by_css_selector("#pagelet_timeline_main_column ._4-u2._4-u8 ._4-u2._4-u8 ._5pcq abbr")
        date = dates[-1].get_attribute("title")[:9].replace("-","")
        if int(date) < int(first_date):
            break
    except:
        time.sleep(5)

# 게시물이 올라온 날짜를 크롤링 해서 리스트에 넣는 코드        
dates = driver.find_elements_by_css_selector("#pagelet_timeline_main_column ._4-u2._4-u8 ._4-u2._4-u8 ._5pcq abbr")
for date in dates:
    if int(date.get_attribute("title")[:9].replace("-","")) >= first_date:
        dates_list.append(date.get_attribute('title'))
nums = len(dates_list)

# 게시물에 존재하는 Text
contents = driver.find_elements_by_css_selector("#pagelet_timeline_main_column ._4-u2._4-u8 ._4-u2._4-u8 .userContent")
for content in contents[:nums]:
    k = content.find_elements_by_css_selector('p:first-child')
    if k:
        contents_list.append(k[0].text)
    else:
        contents_list.append('')

# 댓글과 공유 개수    
comments = driver.find_elements_by_css_selector("#pagelet_timeline_main_column ._4-u2._4-u8 ._4-u2._4-u8 ._ipn.clearfix._-5d ._ipo a")
for comment in comments[:nums*2]:
    comments_list.append(comment.text)

# %% [markdown]
# ![facebookerr2](material/errorcase2.png)

# %% [markdown]
# ![facebookerr1](material/errorcase1.png)

# %% [markdown]
# 감사합니다
